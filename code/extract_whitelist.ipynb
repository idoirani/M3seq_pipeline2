# %%
import pandas as pd
import os

# %%
df = pd.read_csv('/scratch/gpfs/ziyangc/PASA/ScRNAseq/new/input/whitelist/whitelist2.txt', sep='\t', header=None)
df.head()
# Out:
#                   0                                                  1     2  \
# 0  AAAAAAAAAAAAAAAA  AAAAAAAAAAAAAAAT,AAAAAAAAAAAAAACA,AAAAAAAAAAAA...  9941
# 1  AAACAACGAAAGACAT  AAAAAACGAAAGACAT,AAACAAAGAAAGACAT,AAACAACCAAAG...   524
# 2  AAACAACGAAAGCTAA  AAAAAACGAAAGCTAA,AAACAAAGAAAGCTAA,AAACAACCAAAG...   380
# 3  AAACAACGAAAGTTAG  AAAAAACGAAAGTTAG,AAACAAAGAAAGTTAG,AAACAACCAAAG...   644
# 4  AAACAACGAAATCCGT  AAACAACAAAATCCGT,AAACAACCAAATCCGT,AAACAACGAAAT...   310
#
#                                                    3
# 0  390,199,29,181,171,40,235,229,62,148,149,29,15...
# 1                1,1,1,3,5,6,3,1,1,1,2,1,1,1,5,1,1,1
# 2               2,1,2,15,7,8,4,1,1,1,7,3,1,1,1,3,1,1
# 3          4,4,7,3,1,2,4,6,1,3,2,2,1,1,1,3,1,1,1,3,1
# 4                               10,1,1,6,2,1,1,1,1,1

# %%
df[0]
# Out:
# 0        AAAAAAAAAAAAAAAA
# 1        AAACAACGAAAGACAT
# 2        AAACAACGAAAGCTAA
# 3        AAACAACGAAAGTTAG
# 4        AAACAACGAAATCCGT
#                ...
# 77539    TTTGGGATGTAGGTTC
# 77540    TTTGGGATGTCCCGTT
# 77541    TTTGGGATGTCTGGGC
# 77542    TTTGGGATGTGAGGCA
# 77543    TTTGGGATGTGGCTTA
# Name: 0, Length: 77544, dtype: object

# %%
with open('../input/whitelist/whitelist_umitools.txt', 'w') as f:
    for i in df[0]:
        f.write(i+'\n')
